# %% [markdown]
# # Analiza slovenskih podatkov za PARSEME shared task 1.1 on verbal MWE identification
#
# ## Predstavitev problema
#
# Pri treniranju modela zmagovalnega programa [traversal](https://github.com/kawu/traversal) je model ustvarjen, vendar ne deluje na *testnih podatkih*.
#
# Model se trenira v skadu z navodili v datoteki [README.md](https://github.com/kawu/traversal#training). Podatki za trening (`train` in `dev`), kot tudi za testiranje so vzeti iz uradne spletne strani [LINDAT/CLARIN Repository Home](https://lindat.mff.cuni.cz/repository/xmlui/handle/11372/LRT-2842).
#
# Možna ralaga je, da težava pri generiranju slovenskih `.cupt` datotek. Slovenske datoteke v obeh različicah `PARSEME shared task` nimajo `UPOS` tagov, ampak zavestno uporavljajo `JOS` tage. V specifikaciji formata `CoNLL-U` in posledično `cupt`, ki je razširjena različica tega formata, je določeno, da je 4 stolpec `UPOS: Universal part-of-speech tag.`, torej eden izmed [17-ih oblik](https://universaldependencies.org/u/pos/index.html), ki morajo biti napisani z velikimi tiskanimi črkami.
#
# ## Predlog dela
#
# Najprej bomo pogledali, ali imajo tudi drugi jeziki svoje različice `POS` tagov namesto `UPOS` tage. Če to drži, vemo, da je izjema le pri slovenskih datotekah, zato bomo s pomočjo pomožnega
#
# ## Opombe
#
# Če želite testirati kodo, upoštevajte ta navodila:
#
# * datotek z besedili naj bodo v podmapi `data/1.0` (POSIX) oziroma `data\1.0` (Windows).
#   V kolikor niso, prosim usterzno poravite spremenljivko `PATH_TO_FILES`.
# * namestite naslednje knjižnice za `Python3`:
#     - `jupyterlab`
#     - `pyconll`

# %%
import os

import pyconll

# %%
# Constant variables
# ------------------
PATH_TO_FILES = 'data'

UPOS_TAGS_V2 = { 
    # https://universaldependencies.org/u/pos/index.html
    "ADJ": "adjective",
    "ADP": "adposition",
    "ADV": "adverb",
    "AUX": "auxiliary",
    "CCONJ": "coordinating conjunction",
    "DET": "determiner",
    "INTJ": "interjection",
    "NOUN": "noun",
    "NUM": "numeral",
    "PART": "particle",
    "PRON": "pronoun",
    "PROPN": "proper noun",
    "PUNCT": "punctuation",
    "SCONJ": "subordinating conjunction",
    "SYM": "symbol",
    "VERB": "verb",
    "X": "other"
}

UPOS_TAGS_V1 = {
    # http://universaldependencies.org/docsv1/u/pos/index.html
    "ADJ": "adjective",
    "ADP": "adposition",
    "ADV": "adverb",
    "AUX": "auxiliary verb",
    "CONJ": "coordinating conjunction",
    "DET": "determiner",
    "INTJ": "interjection",
    "NOUN": "noun",
    "NUM": "numeral",
    "PART": "particle",
    "PRON": "pronoun",
    "PROPN": "proper noun",
    "PUNCT": "punctuation",
    "SCONJ": "subordinating conjunction",
    "SYM": "symbol",
    "VERB": "verb",
    "X": "other"
}

# %%
def parse_file(path_to_file, upos_tags=[]):
    """Get the UPOS tags with the pyconll library or an 
    ad hoc cupt parser.
    
    Note
    ----
        The cupt parser assumes that the columns are:
    ID FORM LEMMA UPOS XPOS FEATS HEAD DEPREL DEPS MISC PARSEME:MWE

    Attributes
    ----------
    path_to_file: str
        A path to the conllu or cupt file.
    
    upos_tags: list
        A list of UPOS tags, either V1, V2 or both.
    
    Returns
    -------
    list
        A list of tuples with a path, filename, sentence start line, token form and upos
    """
    # Get the path, filename and extension
    filename, ext = os.path.splitext(path_to_file)

    found_tags = []
    
    # Check that the file has at least one valid UPOS tag
    file_is_blank = True
    
    # TODO: remove duplicate logic in the generation of the report
    if ext == ".conllu":
        conllu = pyconll.load_from_file(path_to_file)
        for sentence in conllu:
            for token in sentence:
                # Check if the UPOS is not a "_", marking a missing tag
                # which pyconllu parses as None
                upos_tag = token.conll().split("\t")[3]
                if token.upos not in upos_tags and upos_tag != "_":
                    report = (
                        path_to_file,
                        sentence.start_line_number,
                        token.form,
                        token.upos
                    )
                    found_tags.append(report)
                else:
                    file_is_blank = False
    else:
        for index, line in enumerate(open(path_to_file).read().splitlines()):
            if not line or line.startswith("#"):
                continue
            line_as_list = line.split("\t")
            upos_tag = line_as_list[3].strip()
            if upos_tag not in upos_tags and upos_tag != "_":
                report = (
                    path_to_file,
                    index,
                    line_as_list[1],
                    upos_tag
                )
                found_tags.append(report)
            else:
                file_is_blank = False
    if file_is_blank:
        report = (path_to_file, "File has no UPOS tags.")
        found_tags.append(report)
    return found_tags

        
def check_upos_tags(path, schema=None):
    """Checks all conllu files in a given folder or a single conllu file if the
    upos tags are Universal POS tags and returns a list of places where there the
    UPOS tags do not conform to the schema.
    
    Notes
    -----
    It checks against the V1 and V2 of the UPOS UD version.
    For the purpose of this task, the only difference is the POS tag
    for a coordinating conjunction.
    
    # http://universaldependencies.org/docsv1/u/pos/index.html
    # https://universaldependencies.org/u/pos/index.html
    
    Attributes
    ----------
    path: str or list
        A path name or a list of paths to join.
    schema: str
        Version one ("v1")  or two ("v2"). If non is given, both schemas are checked.

    Returns
    -------
    list
        All the tags that don't have a POS tag
    """
    path = os.path.join(*path) if isinstance(path, list) else path
    all_files = os.listdir(path) if os.path.isdir(path) else path
    files_to_check = [file for file in all_files if file.endswith(".conllu") or file.endswith(".cupt")]

    if not files_to_check:
        raise Exception("No CoNLL-u  or cupt file(s) to check.")

    upos_tags_v1 = list(UPOS_TAGS_V1.keys())
    upos_tags_v2 = list(UPOS_TAGS_V2.keys())

    if schema == "v1":
        upos_tags = upos_tags_v1
    elif schema == "v2":
        upos_tags = upos_tags_v2
    else:
        upos_tags = set(upos_tags_v1 + upos_tags_v2)

    tags = []

    for file in files_to_check:
        found = parse_file(os.path.join(path, file), upos_tags=upos_tags)
        tags += found
    return tags

# %%
# Search for langugage where UPOS tags are not being used
path = os.path.join(PATH_TO_FILES, "1.0")
found = []

for folder in os.listdir(path=path):
    if not os.path.isdir(os.path.join(path, folder)):
        continue
    try:
        wrong_tags = check_upos_tags(os.path.join(path, folder))
        found += wrong_tags
    except:
        continue
languages = set([r[0] for r in found])
languages
# Out:
# {'data/1.0/FR/test.conllu',
#  'data/1.0/FR/train.conllu',
#  'data/1.0/HU/test.conllu',
#  'data/1.0/HU/train.conllu',
#  'data/1.0/IT/test.conllu',
#  'data/1.0/IT/train.conllu',
#  'data/1.0/RO/test.conllu',
#  'data/1.0/RO/train.conllu',
#  'data/1.0/SL/test.conllu',
#  'data/1.0/SL/train.conllu'}

# %%
# Compare the tags
for file in languages:    
    c = pyconll.load_from_file(file)
    upos = []
    for sentence in c:
        for token in sentence:
            upos_tag = token.conll().split("\t")[3]
            upos.append(upos_tag)
    print(f'{file}: {", ".join(set(upos))}')
# Out:
# data/1.0/IT/test.conllu: I, B, V, T, F, D, X, C, E, P, A, R, S, N
# data/1.0/RO/test.conllu: Pp1-po, Dd3mso---e, Pd3mpo, Ds1fp-s, Dd3-po---o, SCOLON, Pi3mpr, Tifso, Pp1-pr, RPAR, Ncmprn, Ncfsry, Moms-ly, Dd3mso---o, Vmip1p, Afpfsry, Mcfsrln, Vmg, Ps3---sf, Tdmsr, Pd3fpr, Dd3fso---o, Ps3fsrs, Ncmpoy, Mo-s-r, Dw3fso, Rg, Mc-p-l, Mcfsoln, Ncmsrn, Ncfpon, Pi3mso, Qs, Npfsry, Pi3-sr, Vmii1p, M, Afpmpry, QUOT, Vmip2s, Ds3mp-s, Dh1mp, Ds3ms-s, Pd3fpo, Ncfsvy, Vmii1s, Momprln, Di3mpr, Dd3fsr, STAR, Dd3fpr, Ds3---sm, Afpmsrn, Pp1-sr, Tdfso, Vmip3s, Vmmp2p, Mcfprln, Mofsrln, Di3fpo, Npmsrn, Pz3msr, Tsmpr, Di3mso, Afpfsoy, Momprly, Px2-pr, Dd3msr, Mlfpo, Mffsrln, Qn, Di3-sr, Mofsoly, Afpfpry, Pi3msr, Tsfpr, Cc, Dd3fsr---e, Afpfpon, Dd3fpr---o, Tdfpo, Pw3--r, Pp3-so, Np, Pd3-po, Pp3-po, Mcmsoln, SLASH, Tdmpo, Pp3mpr, Vmil3p, Ps3ms-s, Px3--o, Dw3msr, Vmis3s, Mofs-ly, Sp, Mcfp-l, Pw3mso, Ncfsoy, Vmsp1p, Afpmprn, Ds1ms-s, Ncfpry, Di3fso, Mcmp-l, Ps1fsrp, Afpfsrn, Dd3fpr---e, Dw3mso, Afpmpoy, Ps3---p, Afpfpoy, Ds1mp-p, Tdmso, Pi3fpr, Ncmsry, X, Ds1fsop, Mcfpoln, Ds3fsrs, Ncmsvy, Dd3msr---e, Pw3-po, Ps1ms-s, Pp2-so, Vmip1s, COLON, Ps3fp-s, Npmsoy, Ps1fsrs, Ncfsrn, RSQR, Npfsrn, Afpfson, Di3fpr, Tdfpr, PERIOD, Afpfprn, Npfsoy, Pd3mso, Tdfsr, PERCENT, Npmpoy, Npmson, Dw3fpr, Cs, AMPER, Ds1mp-s, Tifsr, I, Vmis3p, Tsfsr, Ds3---sf, Tfmso, Mofprly, Pp2-pr, Pp3msr, Pw3fso, Npfprn, Ncfson, Mcfpoly, Pi3-po, Vaip2p, Momsrly, Vmmp2s, Dd3mpr---o, Pp1-so, Di3mpo, Y, Pi3--r, Van, Ncfprn, Px3--r, Pd3mpr, QUEST, Px1-sr, Vmip2p, COMMA, Qz, Vaip3s, Npmpry, Mlfpr, Dd3mpr, Pi3fsr, Pd3fso, Ncmpvy, Pi3fso, DASH, Pp2-po, Afp, Vmis2s, Ncmpry, Dw3-po, Ds1fsrp, Ds3---p, Pz3mso, Mofsrly, Pd3fsr, Dw3--r, Vmsp2p, Dd3mpr---e, Pp3fsr, Tdmpr, Afpfsvy, Dd3-po---e, LPAR, Vmsp3, LSQR, Tsmsr, Npfpry, Di3msr, Vmp, Afpmson, Ps1ms-p, Ds1fp-p, Npmsry, EXCL, Vmn, Ncmsoy, Timsr, Dd3msr---o, Ds3fp-s, DBLQ, Pd3msr, Pp2-sr, Dh3fs, Ps3mp-s, Vmip3p, Timso, Vmii3p, Vmii2p, Vaip3p, Vmil3s, Ds3fsos, Dd3fso---e, Vaip1s, Afpmsry, Npfpon, Vmii2s, Mofpoly, Px1-pr, Afpmsoy, Di3--r, Pp3fpr, HELLIP, Momsoly, Npmprn, Vaip2s, Dd3fsr---o, Ncmson, Mcmsrln, Ds1ms-p, Momsrln, Tifpo, Vmii3s, Ncfpoy, Di3-po, Di3fsr, PLUS, Vaip1p, Vmsp1s, Pp3fso, Vmsp2s
# data/1.0/SL/train.conllu: Zotzdr--k, Gp-d-dz, ?, Zk-mmt, Zp-ser, Pppser, Slsmi, Psnmetn, Zn-mmd, Zc-sdi, Pppmeid, Zstmetem, Pdnsdr, Zstzemm, Kbgzdt, Zl-zer, Zz-mei, Pdnmdd, Pppmeo, Ggvstd, Zz-mer, Ppnzmm, Somdo, Zotmet--z, Zotsmo, Kbdsei, Zstmeoem, Zotmed--k, Zop-dr, Zstseoem, Zl-mer, …, Ppnmdo, Pppsed, Zstmetm, Zc-zer, Kbzser, Zstmmmem, Zp-smm, Kbvmmo, Zl-zed, Zspmdod, Kbzzed, Zstsmoem, Ppnsmd, Zv-med, Sometn, Somdr, Ppnmetn, Kbgsmo, Zotsed--k, Zspsmre, ×, Slsem, Zp-mem, Zotsmm, Psnmem, Zc-zet, Zc-zem, Zp-mer, Kbg-mm, Ppnzmo, Gp-std-n, Zod-eo, Zotzmt--z, Kbgmmr, Zc-sem, Slzmi, Pppsmd, Slseo, Zspmmid, Zotmeo, Zn-zmm, Zn-mmt, Zn-sei, Zsdzerd, Ppsmmm, Zspzdie, Ppnzdr, Kbgzmo, Zop-dt, Zc-zdt, Ppszmr, Sommt, Ggvd-es, Kbvzet, Zp-zmd, Pdnzdi, Zk-smr, Zc-smt, Psnset, °, Ggnd-dz, Zopmdi, Zv-zei, Zstmmrez, Psnzmm, #, Zod-ei, Zstzmiez, Zspmerm, Zotmmt, Zstzmrem, Sometd, Zl-zmi, Zstzeiez, Kbvsei, Zsdzere, Sozer, Zotmmd, Pppzmr, Zc-mmr, Zstzeom, Ppnzem, Sozmr, Somdi, Ppnmdi, Zspzeoe, Ggdd-dz, Zstzmmem, Zstmerem, Zotser--k, Psnzmi, Zv-mdo, Ggnsdd, Sozmd, Gp-ptd-n, Zop-ed--k, Kbvzmd, Zstzerd, Ppnmeo, Slzmt, !, Zv-zmt, Pppsmi, Zotmdt--k, Ppnsdr, Zotzmr--k, Slmeo, Zl-met, Zspsmte, Zn-zdi, -, Ggdspd, Zl-set, Zspsemm, Ggnd-em, Vp, Sozmt, Zstmmmm, Ggnspd-n, Zn-zeo, Sozdo, Zotzem, Psnzer, Psnmein, Kbgsdt, Ppssem, Pdnzmt, Zod-mm, Sosdt, Sosdo, Zotmdo, Pdnmmt, Zsdzetm, Somdt, Zv-zmo, Zotzet--k, Zk-zer, Zp-zeo, Zsdzeod, Pdnsmo, Kbvzmt, ”, Zv-zdo, Zk-met, Zstzerm, Zk-zmi, Ppszmm, Zn-zer, Sommr, Zspzetm, Zod-mt, Sosdm, Ggnd-es, Zz-met, Zsdmere, Zk-zeo, Zotmer--k, Pdnsdi, Zv-mem, Sozeo, Zsdsdrd, Kbvzed, Zstmerm, Pdnmdi, Gp-sde-n, Somed, Slmmo, Zspmeim, Zspmeid, Zspzedm, Ggdvde, Pdnzmm, Zv-zmd, Sosei, Slmetn, Slzeo, Zspmeom, /, Ppssmt, Zp-zmm, Zspzeom, Kbvsdt, •, Pdnmdr, Zstsetd, Pppzmd, Slmmi, Zc-zei, Psnmed, Gp-d-em, Pppmmm, Zv-zeo, Zsdzmtm, Kbzzet, Psnzmd, Ppnzmi, Psnzmo, Slmei, Zspmetm, Ppnzdt, Ppszem, Kbvsmr, Ggvvdm, Zspzmre, Ppnzeo, Pdnmein, Zp---d, Zv-ser, Ggnspe-d, Zc-zdi, Pdnzdr, Psnmdi, Zspseid, Psnsmt, Kbzsmr, Zk-meo, Zk-set, Zstzeid, Zn-smm, Gp-stm-n, Gp-ste-n, Dd, Kav, Zc-zmd, Zspmemm, Zod-et--z, Sozed, Zspzeim, Zspsmrm, Zl-zmr, Zz-ser, Zz-zmm, Zotmem, Sosmm, Zk-zmm, Slzer, Kbgmmi, Zop-mm, Ggvspm, Zspzeid, Zstzedm, Zz-seo, Ggvstm, Zspserd, Zstmedem, Kbvzmr, Zop-er, Zstsetm, Gp-vdm, Sozdd, Kbzsmo, Soset, Sommi, Pdnmmi, Zod-et--k, Psnser, Zstzetez, Kbvmmt, Zz-sei, Pdnzer, Pppmmt, Pdnzet, Soseo, Pppmmi, Zl-zei, Zstsetez, Ppnset, Zotmet, Zk-sed, Zk-smm, Ppnmem, Zstsmrez, Ggvd-em, Zc-mem, Pdnzed, Ppssei, Zstzmoem, Zp-smr, Ggdsde, Zspseie, Zp-mmr, Zk-mmr, Zsdsmim, Zc-met, Sozmm, Kbzseo, Zv-smm, Slmmd, Ggvd-ms, M, Zk-zmt, Ppsmem, Zc-smi, Zl-zmt, Zop-er--k, (, Kbzmein, Kbzsmt, Zotsmt--z, Pppzei, Zc-zdr, Pppsmm, Ppszmt, Zp---d--k, Zk-zmr, Zstzerem, Kbzzmi, Zn-zet, Zop-ei, Zk-sem, Ggdd-dm, Ggvn, Kbzmmi, Ppsmer, Pdnmetn, Pppmmo, Zv-zet, Zod-mo, Gp-ppd-n, Kbvzem, Kbvmmm, Kbgsmi, Zstserez, Zc-sei, Kbzzmt, Zotzeo, Zv-sem, Sosmi, Kbgmmd, Ggnd-dm, Zc-zed, Ggnsdm-d, Gp-pdm-n, Zsdsmtm, Zstmmtm, Zstzmrm, Kbvmer, Zz-sem, Zotzmd, Zp-med, Zc-zmo, Zstmemm, Zn-seo, Ppnmetd, Zsdmmrm, Zspmdrd, Ppnser, Ggdd-ez, Kbzzer, Ppnzmt, Zstzmtm, Zstsemez, Sommo, Zodmmi, Zc-zdo, Pdnmmr, Zstsmrd, Kbdzei, –, Zstzeies, Ggnd-mm, Zn-zmt, Kbzset, Zc-mmi, Zc-mdm, Kbzmmt, Zstmeiez, Zsdmmod, ), Zspzete, Zstsmim, Zl-zet, Zop-et--k, Zod-mr, Zspmmim, Zl-sed, Zp---m, Zstmmtez, Zotmed, Ggnstm, Zp-smt, Kbgsmt, Ppsmetd, Somdd, Zv-zer, Rsn, Zz-set, Kbgmdm, Zp-zet, Zspmeie, Kbgmdi, Psnsmm, Zspmete, Zotzed, Zk-mem, Kbgzmi, Psnmeo, Zn-med, Zc-mei, Zk-zmd, &, », Ppsmeo, Zc-zdm, Gp-spd-n, Zp-zdt, Zp-zmt, Kbzmem, Kbdset, Ppnzei, Zotzdt--z, Ppnsdt, Ggnspe, Ggnsde-n, Zod-et, Zstmeoez, Kbdzmr, Zotzet--z, Pppmetd, Zn-met, Kbzmed, Sozdm, Pppzmo, Gp-sdm-d, Zstzetm, Pdnzmd, Pdnser, Kbzmmd, Ggnsdm, Kbvsem, Zspzere, Zn-smt, Kbzmeo, Zl-ser, Ppsseo, Zz-med, Somem, Ggvd-mm, Pdnmmo, Zspzmtm, Zc-meo, Kbgzmm, Zspsete, Ggnd-mz, Psnzdi, Zstzeiem, Psnmer, Zv-smo, Zotsdt--k, Ppszmo, Zstzmrez, Zp-sem, Zstzeoez, Slmed, Z ...
# data/1.0/IT/train.conllu: I, B, V, T, F, D, X, E, P, C, A, R, S, N
# data/1.0/HU/train.conllu: O, V, ;, P, -, N, ,, ..., I, ", T, ], C, :, §, [, Y, M, ., R, (, ), X, +, A, Z, S
# data/1.0/SL/test.conllu: Gp-d-dz, ?, Zk-mmt, Zp-ser, Pppser, Kbdmmo, Psnmetn, Zn-mmd, Zstmetem, Pppmeid, Zstzemm, Kbgzdt, Zl-zer, Zz-mei, Zz-mer, Ggvstd, Pppmeo, Ppnzmm, Somdo, Zotmet--z, Zotsmo, Zstmeoem, Zopzmi, Zotmed--k, Zl-mer, …, Zstsdiez, Ppnmdo, Zc-zer, Zstmmmem, Kbzser, Zp-smm, Zspmdie, Kbzzed, Ppnsmd, Zv-med, Sometn, Somdr, Zstseid, Ppnmetn, Kbgsmo, Zotsed--k, Slsem, Zp-mem, Psnmem, Zc-zet, Zp-mer, Zc-zem, Kbg-mm, Ppnzmo, Gp-std-n, Zspmede, Zotzmt--z, Zc-sem, Kbgmmr, Slzmi, Zotmeo, Zn-mmt, Zn-zmm, Zn-sei, Zsdzerd, Ppnzdr, Zop-dt, Ppszmr, Zc-zdt, Zsdmmie, Sommt, Ggvd-es, Kbvzet, Zk-smr, Zp-zmd, Zc-smt, Psnset, °, Ggnd-dz, Zv-zei, Zstmmrez, #, Zod-ei, Zspmerm, Sometd, Zstzeiez, Kbvsei, Zotmdd, Sozer, Pppzmr, Zc-mmr, Ppnzem, Zspzeoe, Somdi, Sozmr, Zotser--k, Ppnmdi, Ggdd-dz, Zstmerem, Zstzmmem, Psnzmi, Sozmd, Gp-ptd-n, Zop-ed--k, Zstzerd, Ppnmeo, Slzmt, !, Zv-zmt, Zotmdt--k, Pppsmi, Ppnsdr, Zotzmr--k, Slmeo, Zspsmte, -, Ggdspd, Zl-set, Zspsemm, Ggnd-em, Vp, Sozmt, Sozdo, Slzmd, Psnmein, Psnzer, Zotzem, Kbgsdt, Pdnzmt, Sosdt, Sosdo, Zotmdo, Pdnmmt, Zsdzetm, Somdt, Zv-zmo, Zotzet--k, Zk-zer, Zp-zeo, Pdnsmo, Kbvzmt, ”, Kbdzer, Zk-met, Ppszmm, Zk-zmi, Zstzerm, Zod-er--k, Zn-zer, Sommr, Sosdm, Zod-mt, Zspzetm, Ggnd-es, Zk-zeo, Zotmer--k, Pdnsdi, Zv-mem, Sozeo, Zstmerm, Pdnmdi, Gp-sde-n, Somed, Slmmo, Zspmeim, Ggdvde, Pdnzmm, Zv-zmd, Sosei, Slmetn, Slzeo, /, Zp-zmm, Zspzeom, •, Zc-zei, Slmmi, Gp-d-em, Zv-zeo, Pppmmm, Kbzzet, Ppnzmi, Slmei, Psnmdm, Zspmetm, Ppnzdt, Ppszem, Kbvsmr, Ggvvdm, Ppnzeo, Pdnmein, Zp---d, Zv-ser, Ggnspe-d, Zc-zdi, Psnsmt, Zk-meo, Zk-set, Zstzeid, Gp-stm-n, Gp-ste-n, Dd, Kav, Zspmemm, Zc-zmd, Sozed, Zspzeim, Zz-zmm, Zl-zmr, Zz-ser, Kbgmmi, Sosmm, Zk-zmm, Slzer, Zotmem, Zop-mm, Ggvspm, Zstzedm, Zz-seo, Zsdmmdm, Zl-zmo, Kbvzmr, Ggvstm, Sozdd, Zop-er, Gp-vdm, Soset, Sommi, Pdnmmi, Zod-et--k, Psnser, Zz-zmr, Zstzetez, Kbvmmt, Pdnzer, Zz-sei, Zstsetez, Pdnzet, Soseo, Pppmmt, Zl-zei, Pppmmi, Ppnset, Zotmet, Zk-sed, Zk-smm, Ppnmem, Pdnzed, Ggvd-em, Zc-mem, Zp-smr, Ggdsde, Zspseie, Zk-mmr, Zp-mmr, Zsdsmim, Zc-met, Sozmm, Zp-sei, Kbzseo, Zv-smm, Slmmd, Ggvd-ms, M, Zk-zmt, Zc-smi, Zop-er--k, (, Kbzmein, Kbzsmt, Zc-zdr, Pppzei, Zotsmt--z, Zp---d--k, Zk-zmr, Zstzerem, Kbzzmi, Zn-zet, Zop-ei, Zk-sem, Ggdd-dm, Ggvn, Kbzmmi, Pdnmetn, Zv-zet, Zod-mo, Kbvzem, Kbvmmm, Kbgsmi, Zstserez, Zc-sei, Zstzdid, Zv-sem, Zotzeo, Sosmi, Kbzzmt, Ggnd-dm, Zz-zeo, Ggnsdm-d, Zc-zed, Gp-pdm-n, Kbgmmd, Zstmmtm, Kbvmer, Zstzmrm, Zp-med, Zz-sem, Zstmemm, Ppnmetd, Ppnser, Ggdd-ez, Zsdzmie, Kbzzer, Ppnzmt, Zstzmtm, Sommo, Zc-zdo, Zodmmi, Pdnmmr, Zstsmrd, –, Ggnd-mm, Kbzmmt, Kbzset, Zc-mmi, Zc-mdm, Zc-sdt, Zstmeiez, Zn-zmt, ), Zop-et--k, Zod-mr, Zspmmim, Zp---m, Zc-mdd, Zotmed, Ggnstm, Zp-smt, Kbgsmt, Ppsmetd, Somdd, Zsdzdim, Zv-zer, Rsn, Zz-set, Kbgmdm, Zp-zet, Zspmeie, Kbgmdi, Zspmete, Zotzed, Zk-mem, Kbgzmi, Zn-med, Zc-mei, Zk-zmd, &, », Zc-zdm, Gp-spd-n, Kbzmem, Zp-zmt, Ppnzei, Ppnsdt, Ggnspe, Zstmeoez, Ggnsde-n, Zn-met, Kbzmed, Pppmetd, Zotzet--z, Pppzmo, Sozdm, Gp-sdm-d, Zstzetm, Pdnzmd, Pdnser, Kbzmmd, Ggnsdm, Kbvsem, Kbzmeo, Zl-ser, Ppsseo, Somem, Ggvd-mm, Pdnmmo, Zspzmtm, Zc-meo, Kbgzmm, Ggnd-mz, Kbzzdm, Psnmer, Zstzeiem, Zv-smo, Zstzmrez, Zp-sem, Slmed, Vd, Pppset, Zotmmd--k, Ggdd-mz, Gp-d-mz, Ggnste, Zz-zei, Ppnmmi, Zn-zem, Zk-mdi, Zotmmr, Pppzed, Zc-zmi, Psnsmo, Psnmmi, Zop-mt, }, Ppnmer, Zstmemem, Zv-zed, Zstzmim, Zk-mmi, Sozmi, Zp-mmt, Kbzzmr, Kbvmed, Zn-smr, Zp-set, Ppsmeid, Zstmdiem, Zstzerez, Zstsmiem, Zsdseim, Zv-mmr, Pdnzem, Zotsem, Ggnstm-d, Zv-sed, Ggdspm, Zstzeod, Zstmmrm, Pppzeo, Zstsmtm, Zspmmie, Zp-mmo, Zstseiez, Zp-zmo, Ggnvdm, Zv-mei, Slzei, Ppnzet, Zotmdi, Zotzdo, Pppzmt, Kbzsmm, Ggnstm-n, Zk-mei, Kbzmer, Zv-zmi, Zv-mmi, Zstmetd, Ggnm, Pdnzmo, Pdnmdm, Ppsmmo, Zp-zmr, Sosmo, Gp-vde, Gp-sdm-n, Zotmmr--k, Ppnsed, Zstzmiem, Zp-mmm, Zk-mdm, Ggdstd, Pdnmmm, Ggvd-ez, Ppsmdi, Zsdzmim, Zstmeim, Zstzedem, Kbzmmm, Zc-smm, Zc-mer, Gp-d-ez, Ggdsdd, Pdnmetd, Gp-pte-n, Sosmt, Ppnzmr, Zotzet, ’, Zn-mmi, Pdnmet, Ppsmet, Ggdste, Kbvs ...
# data/1.0/FR/test.conllu: PRO, PONCT, I, V, _, CL, ET, ADV, C, P, PREF, A, D, N
# data/1.0/RO/train.conllu: Pp1-po, Mlmpo, Dd3mso---e, Pd3mpo, Ds1fp-s, Dd3-po---o, SCOLON, Pi3mpr, Tifso, Pp1-pr, RPAR, Vmil1p, Ncmprn, Ncfsry, Moms-ly, Dd3mso---o, Ps1mp-s, Vmip1p, Afpfsry, Ds2fp-s, Mcfprly, Mcfsrln, Vmg, Ps3---sf, Tdmsr, Pd3fpr, Dd3fso---o, Ps3fsrs, Ncmpoy, Dd3mpo, Mo-s-r, Dw3fso, Pw3fpr, Rg, Mc-p-l, Mcfsoln, Ncmsrn, Ncfpon, Pi3mso, Qs, Npfsry, Pi3-sr, Vmii1p, Afpmpry, M, Dh3ms, Vmip2s, Ds3mp-s, QUOT, Dh1mp, Ds3ms-s, Mcmsrl, Pd3fpo, Ncfsvy, Vmii1s, Ds2fsrs, Momprln, Di3mpr, Dd3fsr, Dd3fpr, STAR, Ds3---sm, Afpmsrn, Pp1-sr, Tdfso, Vmip3s, Mcfprln, Vmmp2p, Ps3ms-s, Mofsrln, Di3fpo, Npmsrn, Pz3msr, Tsmpr, Ds1fsos, Di3mso, Afpfsoy, Momprly, Dd3msr, Px2-pr, Mlfpo, Ds2fsrp, Vmis1s, Mffsrln, Qn, Di3-sr, Mofsoly, Afpfpry, Pi3msr, Tsfpr, Cc, Vmil1s, Dd3fsr---e, Afpfpon, Dd3fpr---o, Ds2mp-s, Tdfpo, Pw3--r, Pp3-so, Np, Pp3-po, Pd3-po, Mcmsoln, SLASH, Pp3mpr, Tdmpo, Vmil3p, Dh3mp, EQUAL, Px3--o, Dw3msr, Vmis3s, Mofs-ly, Sp, Pw3mso, Mcfp-l, Ncfsoy, Ds2fp-p, Ps2fsrs, Vmsp1p, Afpmprn, Ds1ms-s, Ncfpry, Di3fso, Mcmp-l, Ps1fsrp, Mlmpr, Ps1mp-p, Afpfsrn, Dd3fpr---e, Dw3mso, Afpmpoy, Ps3---p, Afpfpoy, Ds1mp-p, Tdmso, Pi3fpr, Ncmsry, X, Ds1fsop, Vmil2p, Mcfpoln, Pw3fsr, Ds3fsrs, Ncmsvy, Dd3msr---e, Pw3-po, Ps1ms-s, Pp2-so, Vmip1s, COLON, Npmsoy, Ps1fsrs, Ps3fp-s, Ncfsrn, RSQR, Npfsrn, Afpfson, Afpmpon, Tdfpr, Di3fpr, PERIOD, Afpfprn, Npfsoy, Pd3mso, Tdfsr, Npmson, PERCENT, Dw3fpr, Cs, AMPER, Ds1mp-s, Mompoly, Tifsr, I, Vmis3p, Tsfsr, Mofprly, Tfmso, Ds3---sf, Pp2-pr, Pw3fso, Pp3msr, Npfprn, Dw3mpr, Px2-sr, Ncfson, Mcfpoly, Pi3-po, Vaip2p, Momsrly, Vmmp2s, Pp1-so, Di3mpo, Dd3mpr---o, Mofprln, Y, Ds1fsrs, Pi3--r, Van, Ncfprn, Px3--r, Pd3mpr, QUEST, Px1-sr, Vmip2p, COMMA, Qz, Vaip3s, Dd3mpr, Mlfpr, Pd3fso, Pi3fsr, Npmpry, Ncmpvy, Ps2ms-s, Pi3fso, DASH, Pp2-po, Afp, Ncmpry, Dw3-po, Ds1fsrp, Ds3---p, Pz3mso, Mofsrly, Vmsp2p, Dw3--r, Pd3fsr, Mffprln, Dd3mpr---e, Pp3fsr, Tdmpr, Afpfsvy, Dd3-po---e, LPAR, Vmsp3, LSQR, Tsmsr, Mcfsrl, Di3msr, Vmp, Npfpry, Mcfsrly, Ps1ms-p, Afpmson, Ds1fp-p, Npmsry, Dw3fsr, EXCL, Vmn, Ncmsoy, Timsr, Dd3msr---o, Ds3fp-s, DBLQ, Pd3msr, Pp2-sr, Dh3fs, Pp3mso, Ps3mp-s, Vmip3p, Timso, Vmii3p, Dd3fpo, Ps1fp-p, Vaip3p, Vmii2p, Vmil3s, Ds3fsos, Dd3fso---e, Vaip1s, Afpmsry, Npfpon, Vmii2s, Mofpoly, Afpmsoy, Px1-pr, Di3--r, Pp3fpr, HELLIP, Mcmsrln, Npmprn, Ds1ms-p, Dd3fsr---o, Ncmson, Ncmpon, Momsrln, Vaip2s, DOLLAR, Tifpo, Vmii3s, Ncfpoy, Di3-po, Di3fsr, PLUS, Pw3-so, Momsoly, Vaip1p, Vmsp1s, Pp3fso, Vmsp2s
# data/1.0/FR/train.conllu: ADJ, V, ADP, ET, P, PREF, PRON, N, SYM, PONCT, I, PROPN, NUM, INTJ, CL, AUX, PART, C, D, CONJ, PUNCT, _, VERB, PRO, DET, NOUN, ADV, X, SCONJ, A
# data/1.0/HU/test.conllu: O, V, ;, P, Z, -, N, ,, ..., ", T, ], C, :, §, [, Y, M, R, (, ), X, A, ., S

# %%
# Now the same analysis for 1.1
# -----------------------------
# NOTE: for the purpose of this notebook we'll use a simple code
# I have writen a library to read and write `cupt` and `conllu`
# files, but I have to add some good tests before releasing it.
# Search for langugage where UPOS tags are not being used
path = os.path.join(PATH_TO_FILES, "1.1")
found = []

for folder in os.listdir(path=path):
    if not os.path.isdir(os.path.join(path, folder)):
        continue
    try:
        wrong_tags = check_upos_tags(os.path.join(path, folder))
        found += wrong_tags
    except:
        continue
languages = set([r[0] for r in found])
languages
# Out:
# {'data/1.1/EU/dev.cupt',
#  'data/1.1/EU/test.blind.cupt',
#  'data/1.1/EU/test.cupt',
#  'data/1.1/EU/train.cupt',
#  'data/1.1/HU/dev.cupt',
#  'data/1.1/HU/test.blind.cupt',
#  'data/1.1/HU/test.cupt',
#  'data/1.1/HU/train.cupt',
#  'data/1.1/IT/dev.cupt',
#  'data/1.1/IT/test.blind.cupt',
#  'data/1.1/IT/test.cupt',
#  'data/1.1/IT/train.cupt',
#  'data/1.1/TR/dev.cupt',
#  'data/1.1/TR/test.blind.cupt',
#  'data/1.1/TR/test.cupt',
#  'data/1.1/TR/train.cupt'}

# %%
# The slovenian data is missig, that is because it has only blanks
# as demonstrated in this quick example
files = [
    'data/1.1/SL/train.cupt',
    'data/1.1/RO/train.cupt',
    'data/1.1/IT/train.cupt',
    'data/1.1/EU/train.cupt',
    'data/1.1/HU/train.cupt',
    'data/1.1/FR/train.cupt'
]
all_tags = []

for file in files:
    tags = []
    for line in open(file).read().splitlines():
        if not line or line.startswith("#"):
            continue
        line_as_list = line.split("\t")
        upos_tag = line_as_list[3]
        tags.append(upos_tag)
    all_tags.append([file, set(tags)])
    
for lang in all_tags:
    print(f'File: {lang[0]}')
    print('------------------------')
    print(f'{",".join(lang[1])}')
    print()
# Out:
# File: data/1.1/SL/train.cupt
# ------------------------
# _
#
# File: data/1.1/RO/train.cupt
# ------------------------
# ADJ,PUNCT,DET,PROPN,NUM,CCONJ,ADP,SYM,INTJ,AUX,NOUN,ADV,PART,X,SCONJ,VERB,PRON
#
# File: data/1.1/IT/train.cupt
# ------------------------
# I,V,_,T,F,D,N,X,E,C,P,A,R,S,B
#
# File: data/1.1/EU/train.cupt
# ------------------------
# ADJ,BST,ADL,HAOS,IZE,PRON,IOR,INTJ,PRT,PROPN,NUM,SYM,AUX,PART,SNB,ADB,AUR,ADT,CONJ,PUNCT,PUNT,LOT,LAB,VERB,DET,ITJ,NOUN,ADV,X,SIG,ADI
#
# File: data/1.1/HU/train.cupt
# ------------------------
# O,?,V,;,P,....,-,N,,,...,I,",T,],C,:,§,[,Y,M,.,R,%,(,),X,+,A,Z,S
#
# File: data/1.1/FR/train.cupt
# ------------------------
# ADJ,DET,PUNCT,PROPN,NUM,CCONJ,ADP,_,INTJ,SYM,AUX,NOUN,ADV,PART,X,SCONJ,VERB,PRON

# %% [markdown]
# ## Rezultati analize
#
# Kot vidimo Romunščina (`RO`) in Slovenščina (`SL`) uporabljata `XPOS` namesto `UPOS`, metdemt ko imajo Francoščina, Madžardščina in Italijanščina svoje različice UPOS oznak.
#
# Ne glede na to, pa noben od naštetih jeziko, razen slovenščine, nima teh težav v različici [1.1](https://gitlab.com/parseme/sharedtask-data/tree/master/1.1), kjer je samo za slovenščino seznam prazen.
#
# Naslednji korak bo torej popraviti slovenske datoteke, tako da bomo `XPOS` oznake prekopirali is kolone za `UPOS` v kolono za `XPOS` in `UPOS` dobili iz začetnih (dveh) črk `XPOS` oznak.

# %%
# JOS to UPOS V1 maping
JOS_TO_UPOS = {
    "S": "NOUN",
    "G": "VERB",
    "P": "ADJ",
    "R": "ADV",
    "Z": "PRON",
    "K": "NUM",
    "D": "ADP", # https://universaldependencies.org/u/pos/all.html#adp-adposition
    "V": {
     "p": "CONJ",
     "d": "SCONJ"
     },
     "L": "PART",
     "M": "INTJ",
     "O": "_",
     "N": "X"
}

# %%
def lookup_upos_tag(word, jos_tag):
    """Gets the UPOS tag for a given JOS token.
    
    Note:
        The implementation is very crude.
        
    Attributes
    ----------
    word: str
        The word in it's original form
    
    jos_tag: str
        An XPOS tag for the slovenian language
    
    Returns
    -------
    str
        The V1 UPOS tag for a given word
        
    
    """
    if word in [".", ",", "(", ")"]:
        return "PUNCT"
    upos_tag = JOS_TO_UPOS.get(jos_tag[0], "_")
    # Exception for conjuctions
    # http://nl.ijs.si/jos/msd/html-sl/msd.C.html
    if isinstance(upos_tag, dict):
        upos_tag = upos_tag.get(jos_tag[1], "_")
    return upos_tag

# Open files
path_to_sl = os.path.join(PATH_TO_FILES, "1.1", "SL")
files = {}
for file in os.listdir(path=path_to_sl):
    filename, ext = os.path.splitext(file)
    if ext != ".cupt":
        continue
    opened_file = open(os.path.join(path_to_sl, file)).read().splitlines()
    files[filename] = opened_file
print(list(files.keys()))
# Out:
# ['dev', 'test', 'test_with_upos', 'train_with_upos', 'dev_with_upos', 'test.blind', 'train', 'test.blind_with_upos']

# %%
# Add UPOS tags with a simple loop
for file_name in files.keys():
    file = files[file_name]
    for index in range(len(file)):
        line = file[index]
        if not line or line.startswith("#"):
                continue
        line_as_list = line.split("\t")
        upos = lookup_upos_tag(line_as_list[1], line_as_list[4])
        line_as_list[3] = upos
        file[index] = "\t".join(line_as_list)
    with open(os.path.join(path_to_sl, file_name + "_with_upos.cupt"), "w") as f:
        for i, row in enumerate(file):
           f.write(row + "\n")

# %%
# Test the writen files
cupt = open("data/1.1/SL/test.cupt").readlines()
with_upos = open("data/1.1/SL/test_with_upos.cupt").readlines()
print(f'Original len: {len(cupt)}, with upos: {len(with_upos)}')
# Out:
# Original len: 46506, with upos: 46506

# %%
# Some more tests
cupt_vid_len = len([line for line in cupt if line and not line.startswith("#") and "VID" in line])
with_upos_vid_len = len([line for line in with_upos if line and not line.startswith("#") and "VID" in line])
cupt_vid_len == with_upos_vid_len
# Out:
# True
